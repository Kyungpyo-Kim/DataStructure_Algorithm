# %% [markdown]
# 출처
# https://swexpertacademy.com/main/learn/course/subjectDetail.do?courseId=AVuPDN86AAXw5UW6&subjectId=AWOVGOEKqeoDFAWg

# %% [markdown]
# 학습개요
# - SW 문제해결 역량강화를 목표로 자료구조의 지식 습득 및 실제 구현 능력을 배양하는 과정입니다.
#
# 학습목표
# 1. 컴퓨터에서 문자를 표현하는 방법에 대해 이해한다.
# 2. 컴퓨터에서 문자열을 저장하는 방식을 이해하고, 이를 활용할 수 있다.
# 3. 문자열을 조작하는 방법을 이해하고 이를 활용할 수 있다.
# 4. 문자열을 정수로, 정수를 문자열로 변환하는 프로그램을 작성할 수 있다.
# 5. 패턴 매칭에 대해 이해하고, 설명할 수 있다.
# 6. 고지식한 패턴 매칭 알고리즘을 이해하고 활용할 수 있다.
# 7. KMP알고리즘의 동작 방식을 이해하고 설명할 수 있다.
# 8. 보이어-무어 알고리즘의 동작 방식을 이해하고 설명할 수 있다.

# %% [markdown]
# ## 4864. [파이썬 S/W 문제해결 기본] 3일차 - 문자열 비교
#
# ※ SW Expert 아카데미의 문제를 무단 복제하는 것을 금지합니다.
#
#
#
# 두 개의 문자열 str1과 str2가 주어진다. 문자열 str2 안에 str1과 일치하는 부분이 있는지 찾는 프로그램을 만드시오.
#
# 예를 들어 두 개의 문자열이 다음과 같이 주어질 때, 첫 문자열이 두번째에 존재하면 1, 존재하지 않으면 0을 출력한다.
#
#
# ABC
#
# ZZZZZABCZZZZZ
#
# 두번째 문자열에 첫번째 문자열과 일치하는 부분이 있으므로 1을 출력.
#
#
# ABC
#
# ZZZZAZBCZZZZZ
#
# 문자열이 일치하지 않으므로 0을 출력.
#
#
#
#
# [입력]
#
#
# 첫 줄에 테스트 케이스 개수 T가 주어진다.  (1≤T≤50)
#
#
# 다음 줄부터 테스트 케이스 별로 길이가 N인 문자열 str1과 길이가 M인 str2가 각각 다른 줄에 주어집니다. (5≤N≤100, 10≤M≤1000, N≤M)
#
#
#
# [출력]
#
#
# 각 줄마다 "#T" (T는 테스트 케이스 번호)를 출력한 뒤, 답을 출력한다.
#
#
#
# ```
# 입력:
# 3
# XYPV
# EOGGXYPVSY
# STJJ
# HOFSTJPVPP
# ZYJZXZTIBSDG
# TTXGZYJZXZTIBSDGWQLW
#
# 출력:
# #1 1
# #2 0
# #3 1
# ```

# %%
# Make input file
f = open("input.txt", "w")
f.write("3\n")
f.write("XYPV\n")
f.write("EOGGXYPVSY\n")
f.write("STJJ\n")
f.write("HOFSTJPVPP\n")
f.write("ZYJZXZTIBSDG\n")
f.write("TTXGZYJZXZTIBSDGWQLW\n")
f.close()

# %%
# for Jupyter Notebook
###
f = open("input.txt", "r")
input = f.readline
###

T = int(input())

for test_case in range(1, T + 1):

    str1 = input().rstrip('\n')
    str2 = input().rstrip('\n')
    
    result = 0
    
    idx = len(str1)
    
    while idx < len(str2)+1:
        if str1 == str2[idx-len(str1):idx]:
            result = 1
            break
        else:
            if idx == len(str2):
                break
            for _ in range(len(str1)):
                idx += 1
                if str1[0] == str2[idx-len(str1)]:
                    break
                    
    print("#"+str(test_case), result)
# Out:
# #1 1
# #2 0
# #3 1

# %% [markdown]
# ## 4861. [파이썬 S/W 문제해결 기본] 3일차 - 회문
#
# ※ ※ SW Expert 아카데미의 문제를 무단 복제하는 것을 금지합니다.
#
#
#
# ABBA처럼 어느 방향에서 읽어도 같은 문자열을 회문이라 한다. NxN 크기의 글자판에서 길이가 M인 회문을 찾아 출력하는 프로그램을 만드시오.
#
# 회문은 1개가 존재하는데, 가로 뿐만 아니라 세로로 찾아질 수도 있다.
#
#
# 예를 들어 N=10, M=10 일 때, 다음과 같이 회문을 찾을 수 있다.
#
#
# (그림 없음)
#
#
# [입력]
#
#
# 첫 줄에 테스트 케이스 개수 T가 주어진다.  1≤T≤50
#
# 다음 줄부터 테스트케이스의 첫 줄에 N과 M이 주어진다. 10≤N≤100, 5≤M≤N
#
# 다음 줄부터 N개의 글자를 가진 N개의 줄이 주어진다.
#
#
#
# [출력]
#
#
# 각 줄마다 "#T" (T는 테스트 케이스 번호)를 출력한 뒤, 답을 출력한다.
#
# ```
# 입력:
# 3
# 10 10
# GOFFAKWFSM
# OYECRSLDLQ
# UJAJQVSYYC
# JAEZNNZEAJ
# WJAKCGSGCF
# QKUDGATDQL
# OKGPFPYRKQ
# TDCXBMQTIO
# UNADRPNETZ
# ZATWDEKDQF
# 10 10
# WPMACSIBIK
# STWASDCOBQ
# AMOUENCSOG
# XTIIGBLRCZ
# WXVSWXYYVU
# CJVAHRZZEM
# NDIEBIIMTX
# UOOGPQCBIW
# OWWATKUEUY
# FTMERSSANL
# 20 13
# ECFQBKSYBBOSZQSFBXKI
# VBOAIDLYEXYMNGLLIOPP
# AIZMTVJBZAWSJEIGAKWB
# CABLQKMRFNBINNZSOGNT
# NQLMHYUMBOCSZWIOBINM
# QJZQPSOMNQELBPLVXNRN
# RHMDWPBHDAMWROUFTPYH
# FNERUGIFZNLJSSATGFHF
# TUIAXPMHFKDLQLNYQBPW
# OPIRADJURRDLTDKZGOGA
# JHYXHBQTLMMHOOOHMMLT
# XXCNJGTXXKUCVOUYNXZR
# RMWTQQFHZUIGCJBASNOX
# CVODFKWMJSGMFTCSLLWO
# EJISQCXLNQHEIXXZSGKG
# KGVFJLNNBTVXJLFXPOZA
# YUNDJDSSOPRVSLLHGKGZ
# OZVTWRYWRFIAIPEYRFFG
# ERAPUWPSHHKSWCTBAPXR
# FIKQJTQDYLGMMWMEGRUZ
#
# 출력:
# #1 JAEZNNZEAJ
# #2 MWOIVVIOWM
# #3 TLMMHOOOHMMLT
# ```

# %%
# Make input file
f = open("input.txt", "w")
f.write("3\n")
f.write("10 10\n")
f.write("GOFFAKWFSM\n")
f.write("OYECRSLDLQ\n")
f.write("UJAJQVSYYC\n")
f.write("JAEZNNZEAJ\n")
f.write("WJAKCGSGCF\n")
f.write("QKUDGATDQL\n")
f.write("OKGPFPYRKQ\n")
f.write("TDCXBMQTIO\n")
f.write("UNADRPNETZ\n")
f.write("ZATWDEKDQF\n")
f.write("10 10\n")
f.write("WPMACSIBIK\n")
f.write("STWASDCOBQ\n")
f.write("AMOUENCSOG\n")
f.write("XTIIGBLRCZ\n")
f.write("WXVSWXYYVU\n")
f.write("CJVAHRZZEM\n")
f.write("NDIEBIIMTX\n")
f.write("UOOGPQCBIW\n")
f.write("OWWATKUEUY\n")
f.write("FTMERSSANL\n")
f.write("20 13\n")
f.write("ECFQBKSYBBOSZQSFBXKI\n")
f.write("VBOAIDLYEXYMNGLLIOPP\n")
f.write("AIZMTVJBZAWSJEIGAKWB\n")
f.write("CABLQKMRFNBINNZSOGNT\n")
f.write("NQLMHYUMBOCSZWIOBINM\n")
f.write("QJZQPSOMNQELBPLVXNRN\n")
f.write("RHMDWPBHDAMWROUFTPYH\n")
f.write("FNERUGIFZNLJSSATGFHF\n")
f.write("TUIAXPMHFKDLQLNYQBPW\n")
f.write("OPIRADJURRDLTDKZGOGA\n")
f.write("JHYXHBQTLMMHOOOHMMLT\n")
f.write("XXCNJGTXXKUCVOUYNXZR\n")
f.write("RMWTQQFHZUIGCJBASNOX\n")
f.write("CVODFKWMJSGMFTCSLLWO\n")
f.write("EJISQCXLNQHEIXXZSGKG\n")
f.write("KGVFJLNNBTVXJLFXPOZA\n")
f.write("YUNDJDSSOPRVSLLHGKGZ\n")
f.write("OZVTWRYWRFIAIPEYRFFG\n")
f.write("ERAPUWPSHHKSWCTBAPXR\n")
f.write("FIKQJTQDYLGMMWMEGRUZ\n")
f.close()

# %%
# for Jupyter Notebook
###
f = open("input.txt", "r")
input = f.readline
###

T = int(input())

for test_case in range(1, T + 1):

    n, m = map(int, input().split())
    nn = []
    for _ in range(n):
        nn.append(input())
        
    result = None
    for idxRow in range(n):
        if not result == None:
            break
        idxCol = 0
        while n-m >= idxCol:
            cnt = 0
            for j in range( int(m/2) ):
                if nn[idxRow][idxCol+j] == nn[idxRow][idxCol+(m-1)-j]:
                    cnt += 1
                else:
                    break
            if cnt == int(m/2):
                result = nn[idxRow][idxCol:idxCol+(m)] 
                break
            idxCol += 1
           
    for idxCol in range(n):
        if not result == None:
            break
        idxRow = 0
        while n-m >= idxRow:
            cnt = 0
            for j in range( int(m/2) ):
                if nn[idxRow+j][idxCol] == nn[idxRow+(m-1)-j][idxCol]:
                    cnt += 1
                else:
                    break
            if cnt == int(m/2):
                r = str()
                for i in range(m):
                    r += nn[idxRow+i][idxCol]
                result = str(r)
                break
            idxRow += 1
            
    print("#"+str(test_case) , result)
# Out:
# #1 JAEZNNZEAJ
# #2 MWOIVVIOWM
# #3 TLMMHOOOHMMLT

# %% [markdown]
# ## 4865. [파이썬 S/W 문제해결 기본] 3일차 - 글자수
#
# ※ SW Expert 아카데미의 문제를 무단 복제하는 것을 금지합니다.
#
#
# 두 개의 문자열 str1과 str2가 주어진다. 문자열 str1에 포함된 글자들이 str2에 몇 개씩 들어있는지 찾고, 그중 가장 많은 글자의 개수를 출력하는 프로그램을 만드시오.
#
# 예를 들어 str1 = “ABCA”, str2 = “ABABCA”인 경우, str1의 A가 str2에 3개 있으므로 가장 많은 글자가 되고 3을 출력한다.
#
# 파이썬의 경우 딕셔너리를 이용할 수 있다.
#
#
# [입력]
#
# 첫 줄에 테스트 케이스 개수 T가 주어진다.  1≤T≤50
#
# 다음 줄부터 테스트 케이스 별로 길이가 N인 문자열 str1과 길이가 M인 str2가 각각 다른 줄에 주어진다. 5≤N≤100, 10≤M≤1000, N≤M
#
# [출력]
#
# 각 줄마다 "#T" (T는 테스트 케이스 번호)를 출력한 뒤, 답을 출력한다.
#
# ```
# 입력:
# 3
# XYPV
# EOGGXYPVSY
# STJJ
# HOFSTJPVPP
# ZYJZXZTIBSDG
# TTXGZYJZXZTIBSDGWQLW
#
# 출력:
# #1 2
# #2 1
# #3 3
# ```

# %%
# Make input file
f = open("input.txt", "w")
f.write("3\n")
f.write("XYPV\n")
f.write("EOGGXYPVSY\n")
f.write("STJJ\n")
f.write("HOFSTJPVPP\n")
f.write("ZYJZXZTIBSDG\n")
f.write("TTXGZYJZXZTIBSDGWQLW\n")
f.close()

# %%
# for Jupyter Notebook
###
f = open("input.txt", "r")
input = f.readline
###

T = int(input())

for test_case in range(1, T + 1):

    str1 = input()
    str2 = input()
    
    cnt = [0 for _ in range(len(str1))]
    
    for i in range(len(str1)):
        
        for s2 in str2:
            
            if str1[i] == s2:
                cnt[i] += 1
                
    print("#"+str(test_case), max(cnt))
# Out:
# #1 2
# #2 1
# #3 3
